# %%
# %matplotlib inline

import sys
sys.path.append("../../")

from train_model_sm import train

from sklearn.linear_model import LinearRegression
from yellowbrick.regressor import ResidualsPlot, PredictionError

import seaborn as sns
import matplotlib.pyplot as plt

from matplotlib import rcParams
rcParams['figure.figsize'] = (8, 4)
rcParams['figure.dpi'] = 100
rcParams['font.size'] = 8
rcParams['font.family'] = 'sans-serif'
rcParams['axes.facecolor'] = '#ffffff'
rcParams['lines.linewidth'] = 2.0
# Out:
# 2023-08-21 23:53:48.283898: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
hyperparameter={
"num_nearest":60,
"sigma":10,
"learning_rate":0.0019,
"batch_size":250,
"num_neuron":60,
"num_layers":3,
"size_embedded":50,
"num_nearest_geo":20,
"num_nearest_eucli":20,
"id_dataset":'fc',
"epochs":300,
"optimier":'adam',
"validation_split":0.1,
"label":'asi_fc',
"early_stopping": False,
"graph_label":'matrix',
"sequence":'_normalized'
}

# %% [markdown]
# # Model

# %%
spatial = train(**hyperparameter)

# %%
dataset,\
result,\
fit,\
embedded_train,\
embedded_test,\
predict_regression_train,\
predict_regression_test = spatial()
# Out:
# node2vec (83136, 12)
# 2023-08-21 23:53:52.105900: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:52.106206: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:52.106461: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:52.106705: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:52.110645: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:52.110896: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:52.111132: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:52.111355: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:52.111572: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:52.111796: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:52.112013: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:52.112229: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:52.112999: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-21 23:53:52.367251: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:52.367485: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:52.367681: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:52.367872: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:52.368061: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:52.368240: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:52.368420: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:52.368600: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:52.368779: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:52.368958: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:52.369137: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:52.369315: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:53.415308: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:53.415564: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:53.415775: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:53.415976: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:53.416170: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:53.416356: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:53.416538: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:53.416719: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:53.416902: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:53.417067: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22273 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2023-08-21 23:53:53.417403: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:53.417562: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 22273 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:81:00.0, compute capability: 8.6
# 2023-08-21 23:53:53.417844: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:53.418005: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 22273 MB memory:  -> device: 2, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:82:00.0, compute capability: 8.6
# 2023-08-21 23:53:53.418284: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-21 23:53:53.418441: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 22273 MB memory:  -> device: 3, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:c1:00.0, compute capability: 8.6
# self.dist_eucli.shape, self.context_struc_eucli_target.shape, self.n2v_eucli.shape (None, 20) (None, 20, 13) (None, 21, 12)
# self.dist_geo.shape, self.context_geo_target_dist.shape, self.n2v_geo.shape (None, 20) (None, 20, 14) (None, 21, 12)
# WARNING:tensorflow:From /home/smhan/.conda/envs/TF2/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# self.input_phenomenon.shape Tensor("Placeholder:0", shape=(None, 12), dtype=float32)
# self.source_distance.shape (None, 20)
# self.context.shape (None, 20, 14)
# self.n2v.shape (None, 21, 12)
# att_query.shape, att_value.shape (None, 1, 64) (None, 20, 64)
# att_output (None, 64)
# feedforward (None, 60)
# Epoch 1/300
# self.input_phenomenon.shape Tensor("IteratorGetNext:0", shape=(None, 12), dtype=float32)
# self.source_distance.shape (None, 20)
# self.context.shape (None, 20, 14)
# self.n2v.shape (None, 21, 12)
# att_query.shape, att_value.shape (None, 1, 64) (None, 20, 64)
# att_output (None, 64)
# self.input_phenomenon.shape Tensor("IteratorGetNext:0", shape=(None, 12), dtype=float32)
# self.source_distance.shape (None, 20)
# self.context.shape (None, 20, 14)
# self.n2v.shape (None, 21, 12)
# att_query.shape, att_value.shape (None, 1, 64) (None, 20, 64)
# att_output (None, 64)
# 2023-08-21 23:53:57.096250: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-08-21 23:53:57.105506: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7f3c84018710 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-08-21 23:53:57.105531: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2023-08-21 23:53:57.105540: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (1): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2023-08-21 23:53:57.105545: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (2): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2023-08-21 23:53:57.105550: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (3): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2023-08-21 23:53:57.110708: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-08-21 23:53:57.201655: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 236/240 [============================>.] - ETA: 0s - loss: 0.4649 - root_mean_squared_error: 1.6573self.input_phenomenon.shape Tensor("IteratorGetNext:0", shape=(None, 12), dtype=float32)
# self.source_distance.shape (None, 20)
# self.context.shape (None, 20, 14)
# self.n2v.shape (None, 21, 12)
# att_query.shape, att_value.shape (None, 1, 64) (None, 20, 64)
# att_output (None, 64)
#
# Epoch 1: val_loss improved from inf to 0.07416, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/fc/asi_fc_weights.hdf5
# 240/240 [==============================] - 7s 10ms/step - loss: 0.4598 - root_mean_squared_error: 1.6454 - val_loss: 0.0742 - val_root_mean_squared_error: 0.0894 - lr: 0.0019
# Epoch 2/300
# 234/240 [============================>.] - ETA: 0s - loss: 0.0745 - root_mean_squared_error: 0.0899
# Epoch 2: val_loss did not improve from 0.07416
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0747 - root_mean_squared_error: 0.0899 - val_loss: 0.0927 - val_root_mean_squared_error: 0.0977 - lr: 0.0019
# Epoch 3/300
# 236/240 [============================>.] - ETA: 0s - loss: 0.0855 - root_mean_squared_error: 0.1015
# Epoch 3: val_loss improved from 0.07416 to 0.05165, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/fc/asi_fc_weights.hdf5
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0862 - root_mean_squared_error: 0.1024 - val_loss: 0.0517 - val_root_mean_squared_error: 0.0562 - lr: 0.0019
# Epoch 4/300
# 237/240 [============================>.] - ETA: 0s - loss: 0.0843 - root_mean_squared_error: 0.1050
# Epoch 4: val_loss did not improve from 0.05165
# 240/240 [==============================] - 2s 9ms/step - loss: 0.0845 - root_mean_squared_error: 0.1051 - val_loss: 0.1678 - val_root_mean_squared_error: 0.1714 - lr: 0.0019
# Epoch 5/300
# 237/240 [============================>.] - ETA: 0s - loss: 0.0721 - root_mean_squared_error: 0.0964
# Epoch 5: val_loss did not improve from 0.05165
# 240/240 [==============================] - 2s 9ms/step - loss: 0.0727 - root_mean_squared_error: 0.0969 - val_loss: 0.0672 - val_root_mean_squared_error: 0.0693 - lr: 0.0019
# Epoch 6/300
# 236/240 [============================>.] - ETA: 0s - loss: 0.0652 - root_mean_squared_error: 0.0791
# Epoch 6: val_loss did not improve from 0.05165
# 240/240 [==============================] - 2s 9ms/step - loss: 0.0651 - root_mean_squared_error: 0.0790 - val_loss: 0.0807 - val_root_mean_squared_error: 0.0835 - lr: 0.0019
# Epoch 7/300
# 240/240 [==============================] - ETA: 0s - loss: 0.0630 - root_mean_squared_error: 0.0747
# Epoch 7: val_loss did not improve from 0.05165
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0630 - root_mean_squared_error: 0.0747 - val_loss: 0.0595 - val_root_mean_squared_error: 0.0665 - lr: 0.0019
# Epoch 8/300
# 238/240 [============================>.] - ETA: 0s - loss: 0.0634 - root_mean_squared_error: 0.0742
# Epoch 8: val_loss improved from 0.05165 to 0.03976, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/fc/asi_fc_weights.hdf5
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0634 - root_mean_squared_error: 0.0741 - val_loss: 0.0398 - val_root_mean_squared_error: 0.0457 - lr: 0.0019
# Epoch 9/300
# 240/240 [==============================] - ETA: 0s - loss: 0.0479 - root_mean_squared_error: 0.0584
# Epoch 9: val_loss did not improve from 0.03976
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0479 - root_mean_squared_error: 0.0584 - val_loss: 0.0571 - val_root_mean_squared_error: 0.0586 - lr: 0.0019
# Epoch 10/300
# 236/240 [============================>.] - ETA: 0s - loss: 0.0597 - root_mean_squared_error: 0.0758
# Epoch 10: val_loss did not improve from 0.03976
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0598 - root_mean_squared_error: 0.0757 - val_loss: 0.0458 - val_root_mean_squared_error: 0.0503 - lr: 0.0019
# Epoch 11/300
# 240/240 [==============================] - ETA: 0s - loss: 0.0514 - root_mean_squared_error: 0.0645
# Epoch 11: val_loss did not improve from 0.03976
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0514 - root_mean_squared_error: 0.0645 - val_loss: 0.0769 - val_root_mean_squared_error: 0.0785 - lr: 0.0019
# Epoch 12/300
# 239/240 [============================>.] - ETA: 0s - loss: 0.0381 - root_mean_squared_error: 0.1734
# Epoch 12: val_loss did not improve from 0.03976
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0381 - root_mean_squared_error: 0.1732 - val_loss: 0.0572 - val_root_mean_squared_error: 0.0591 - lr: 0.0019
# Epoch 13/300
# 234/240 [============================>.] - ETA: 0s - loss: 0.0344 - root_mean_squared_error: 0.0396
# Epoch 13: val_loss did not improve from 0.03976
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0356 - root_mean_squared_error: 0.0417 - val_loss: 0.0833 - val_root_mean_squared_error: 0.0853 - lr: 0.0019
# Epoch 14/300
# 240/240 [==============================] - ETA: 0s - loss: 0.0072 - root_mean_squared_error: 0.0139
# Epoch 14: val_loss improved from 0.03976 to 0.00381, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/fc/asi_fc_weights.hdf5
# 240/240 [==============================] - 2s 9ms/step - loss: 0.0072 - root_mean_squared_error: 0.0139 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0059 - lr: 1.9000e-04
# Epoch 15/300
# 237/240 [============================>.] - ETA: 0s - loss: 0.0036 - root_mean_squared_error: 0.0058
# Epoch 15: val_loss improved from 0.00381 to 0.00378, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/fc/asi_fc_weights.hdf5
# 240/240 [==============================] - 2s 9ms/step - loss: 0.0036 - root_mean_squared_error: 0.0058 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0055 - lr: 1.9000e-04
# Epoch 16/300
# 235/240 [============================>.] - ETA: 0s - loss: 0.0035 - root_mean_squared_error: 0.0055
# Epoch 16: val_loss improved from 0.00378 to 0.00297, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/fc/asi_fc_weights.hdf5
# 240/240 [==============================] - 2s 9ms/step - loss: 0.0035 - root_mean_squared_error: 0.0055 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0048 - lr: 1.9000e-04
# Epoch 17/300
# 240/240 [==============================] - ETA: 0s - loss: 0.0030 - root_mean_squared_error: 0.0049
# Epoch 17: val_loss did not improve from 0.00297
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0030 - root_mean_squared_error: 0.0049 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0046 - lr: 1.9000e-04
# Epoch 18/300
# 240/240 [==============================] - ETA: 0s - loss: 0.0029 - root_mean_squared_error: 0.0047
# Epoch 18: val_loss did not improve from 0.00297
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0029 - root_mean_squared_error: 0.0047 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0087 - lr: 1.9000e-04
# Epoch 19/300
# 237/240 [============================>.] - ETA: 0s - loss: 0.0046 - root_mean_squared_error: 0.0060
# Epoch 19: val_loss did not improve from 0.00297
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0046 - root_mean_squared_error: 0.0060 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0062 - lr: 1.9000e-04
# Epoch 20/300
# 238/240 [============================>.] - ETA: 0s - loss: 0.0031 - root_mean_squared_error: 0.0046
# Epoch 20: val_loss improved from 0.00297 to 0.00290, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/fc/asi_fc_weights.hdf5
# 240/240 [==============================] - 2s 9ms/step - loss: 0.0031 - root_mean_squared_error: 0.0046 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0041 - lr: 1.9000e-04
# Epoch 21/300
# 236/240 [============================>.] - ETA: 0s - loss: 0.0046 - root_mean_squared_error: 0.0061
# Epoch 21: val_loss did not improve from 0.00290
# 240/240 [==============================] - 2s 9ms/step - loss: 0.0046 - root_mean_squared_error: 0.0061 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0042 - lr: 1.9000e-04
# Epoch 22/300
# 240/240 [==============================] - ETA: 0s - loss: 0.0021 - root_mean_squared_error: 0.0035
# Epoch 22: val_loss improved from 0.00290 to 0.00203, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/fc/asi_fc_weights.hdf5
# 240/240 [==============================] - 2s 9ms/step - loss: 0.0021 - root_mean_squared_error: 0.0035 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0034 - lr: 1.9000e-05
# Epoch 23/300
# 236/240 [============================>.] - ETA: 0s - loss: 0.0020 - root_mean_squared_error: 0.0034
# Epoch 23: val_loss improved from 0.00203 to 0.00198, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/fc/asi_fc_weights.hdf5
# 240/240 [==============================] - 2s 9ms/step - loss: 0.0020 - root_mean_squared_error: 0.0034 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0033 - lr: 1.9000e-05
# Epoch 24/300
# 238/240 [============================>.] - ETA: 0s - loss: 0.0020 - root_mean_squared_error: 0.0034
# Epoch 24: val_loss improved from 0.00198 to 0.00194, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/fc/asi_fc_weights.hdf5
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0020 - root_mean_squared_error: 0.0034 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0033 - lr: 1.9000e-05
# Epoch 25/300
# 234/240 [============================>.] - ETA: 0s - loss: 0.0020 - root_mean_squared_error: 0.0034
# Epoch 25: val_loss improved from 0.00194 to 0.00192, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/fc/asi_fc_weights.hdf5
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0020 - root_mean_squared_error: 0.0034 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0032 - lr: 1.9000e-05
# Epoch 26/300
# 235/240 [============================>.] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0034
# Epoch 26: val_loss did not improve from 0.00192
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0019 - root_mean_squared_error: 0.0034 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0033 - lr: 1.9000e-05
# Epoch 27/300
# 236/240 [============================>.] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0033
# Epoch 27: val_loss improved from 0.00192 to 0.00188, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/fc/asi_fc_weights.hdf5
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0019 - root_mean_squared_error: 0.0033 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0032 - lr: 1.9000e-05
# Epoch 28/300
# 238/240 [============================>.] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0033
# Epoch 28: val_loss improved from 0.00188 to 0.00185, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/fc/asi_fc_weights.hdf5
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0019 - root_mean_squared_error: 0.0033 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0032 - lr: 1.9000e-05
# Epoch 29/300
# 238/240 [============================>.] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0033
# Epoch 29: val_loss improved from 0.00185 to 0.00184, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/fc/asi_fc_weights.hdf5
# 240/240 [==============================] - 2s 9ms/step - loss: 0.0019 - root_mean_squared_error: 0.0033 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0031 - lr: 1.9000e-05
# Epoch 30/300
# 234/240 [============================>.] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0032
# Epoch 30: val_loss improved from 0.00184 to 0.00180, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/fc/asi_fc_weights.hdf5
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0019 - root_mean_squared_error: 0.0032 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0031 - lr: 1.9000e-05
# Epoch 31/300
# 239/240 [============================>.] - ETA: 0s - loss: 0.0018 - root_mean_squared_error: 0.0032
# Epoch 31: val_loss improved from 0.00180 to 0.00177, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/fc/asi_fc_weights.hdf5
# 240/240 [==============================] - 2s 9ms/step - loss: 0.0018 - root_mean_squared_error: 0.0032 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0030 - lr: 1.9000e-05
# Epoch 32/300
# 235/240 [============================>.] - ETA: 0s - loss: 0.0018 - root_mean_squared_error: 0.0032
# Epoch 32: val_loss did not improve from 0.00177
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0018 - root_mean_squared_error: 0.0032 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0030 - lr: 1.9000e-05
# Epoch 33/300
# 234/240 [============================>.] - ETA: 0s - loss: 0.0018 - root_mean_squared_error: 0.0031
# Epoch 33: val_loss improved from 0.00177 to 0.00173, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/fc/asi_fc_weights.hdf5
# 240/240 [==============================] - 2s 9ms/step - loss: 0.0018 - root_mean_squared_error: 0.0031 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0029 - lr: 1.9000e-05
# Epoch 34/300
# 239/240 [============================>.] - ETA: 0s - loss: 0.0018 - root_mean_squared_error: 0.0031
# Epoch 34: val_loss improved from 0.00173 to 0.00169, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/fc/asi_fc_weights.hdf5
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0017 - root_mean_squared_error: 0.0031 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0029 - lr: 1.9000e-05
# Epoch 35/300
# 236/240 [============================>.] - ETA: 0s - loss: 0.0017 - root_mean_squared_error: 0.0030
# Epoch 35: val_loss did not improve from 0.00169
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0017 - root_mean_squared_error: 0.0030 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0029 - lr: 1.9000e-05
# Epoch 36/300
# 235/240 [============================>.] - ETA: 0s - loss: 0.0017 - root_mean_squared_error: 0.0030
# Epoch 36: val_loss improved from 0.00169 to 0.00167, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/fc/asi_fc_weights.hdf5
# 240/240 [==============================] - 2s 9ms/step - loss: 0.0017 - root_mean_squared_error: 0.0030 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0028 - lr: 1.9000e-05
# Epoch 37/300
# 236/240 [============================>.] - ETA: 0s - loss: 0.0017 - root_mean_squared_error: 0.0029
# Epoch 37: val_loss did not improve from 0.00167
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0017 - root_mean_squared_error: 0.0029 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0029 - lr: 1.9000e-05
# Epoch 38/300
# 236/240 [============================>.] - ETA: 0s - loss: 0.0017 - root_mean_squared_error: 0.0029
# Epoch 38: val_loss improved from 0.00167 to 0.00160, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/fc/asi_fc_weights.hdf5
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0017 - root_mean_squared_error: 0.0029 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0028 - lr: 1.9000e-05
# Epoch 39/300
# 239/240 [============================>.] - ETA: 0s - loss: 0.0016 - root_mean_squared_error: 0.0029
# Epoch 39: val_loss improved from 0.00160 to 0.00157, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/fc/asi_fc_weights.hdf5
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0016 - root_mean_squared_error: 0.0028 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0027 - lr: 1.9000e-05
# Epoch 40/300
# 238/240 [============================>.] - ETA: 0s - loss: 0.0016 - root_mean_squared_error: 0.0028
# Epoch 40: val_loss did not improve from 0.00157
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0016 - root_mean_squared_error: 0.0028 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0028 - lr: 1.9000e-05
# Epoch 41/300
# 238/240 [============================>.] - ETA: 0s - loss: 0.0016 - root_mean_squared_error: 0.0028
# Epoch 41: val_loss did not improve from 0.00157
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0016 - root_mean_squared_error: 0.0028 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0027 - lr: 1.9000e-05
# Epoch 42/300
# 236/240 [============================>.] - ETA: 0s - loss: 0.0016 - root_mean_squared_error: 0.0027
# Epoch 42: val_loss improved from 0.00157 to 0.00150, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/fc/asi_fc_weights.hdf5
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0016 - root_mean_squared_error: 0.0028 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0026 - lr: 1.9000e-05
# Epoch 43/300
# 234/240 [============================>.] - ETA: 0s - loss: 0.0016 - root_mean_squared_error: 0.0027
# Epoch 43: val_loss did not improve from 0.00150
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0016 - root_mean_squared_error: 0.0027 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0026 - lr: 1.9000e-05
# Epoch 44/300
# 239/240 [============================>.] - ETA: 0s - loss: 0.0016 - root_mean_squared_error: 0.0027
# Epoch 44: val_loss improved from 0.00150 to 0.00147, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/fc/asi_fc_weights.hdf5
# 240/240 [==============================] - 2s 9ms/step - loss: 0.0016 - root_mean_squared_error: 0.0027 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0025 - lr: 1.9000e-05
# Epoch 45/300
# 237/240 [============================>.] - ETA: 0s - loss: 0.0015 - root_mean_squared_error: 0.0027
# Epoch 45: val_loss did not improve from 0.00147
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0015 - root_mean_squared_error: 0.0027 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0026 - lr: 1.9000e-05
# Epoch 46/300
# 235/240 [============================>.] - ETA: 0s - loss: 0.0015 - root_mean_squared_error: 0.0026
# Epoch 46: val_loss did not improve from 0.00147
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0015 - root_mean_squared_error: 0.0026 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0026 - lr: 1.9000e-05
# Epoch 47/300
# 238/240 [============================>.] - ETA: 0s - loss: 0.0015 - root_mean_squared_error: 0.0026
# Epoch 47: val_loss did not improve from 0.00147
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0015 - root_mean_squared_error: 0.0026 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0025 - lr: 1.9000e-05
# Epoch 48/300
# 238/240 [============================>.] - ETA: 0s - loss: 0.0015 - root_mean_squared_error: 0.0026
# Epoch 48: val_loss improved from 0.00147 to 0.00140, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/fc/asi_fc_weights.hdf5
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0015 - root_mean_squared_error: 0.0026 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0024 - lr: 1.9000e-05
# Epoch 49/300
# 238/240 [============================>.] - ETA: 0s - loss: 0.0015 - root_mean_squared_error: 0.0025
# Epoch 49: val_loss did not improve from 0.00140
# 240/240 [==============================] - 2s 9ms/step - loss: 0.0015 - root_mean_squared_error: 0.0026 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0025 - lr: 1.9000e-05
# Epoch 50/300
# 239/240 [============================>.] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0024
# Epoch 50: val_loss improved from 0.00140 to 0.00138, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/fc/asi_fc_weights.hdf5
# 240/240 [==============================] - 2s 9ms/step - loss: 0.0014 - root_mean_squared_error: 0.0025 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0024 - lr: 1.9000e-06
# Epoch 51/300
# 238/240 [============================>.] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0024
# Epoch 51: val_loss improved from 0.00138 to 0.00135, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/fc/asi_fc_weights.hdf5
# 240/240 [==============================] - 2s 9ms/step - loss: 0.0014 - root_mean_squared_error: 0.0024 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0024 - lr: 1.9000e-06
# Epoch 52/300
# 238/240 [============================>.] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0024
# Epoch 52: val_loss improved from 0.00135 to 0.00135, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/fc/asi_fc_weights.hdf5
# 240/240 [==============================] - 2s 9ms/step - loss: 0.0014 - root_mean_squared_error: 0.0024 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0024 - lr: 1.9000e-06
# Epoch 53/300
# 234/240 [============================>.] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0024
# Epoch 53: val_loss did not improve from 0.00135
# 240/240 [==============================] - 2s 9ms/step - loss: 0.0014 - root_mean_squared_error: 0.0024 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0024 - lr: 1.9000e-06
# Epoch 54/300
# 239/240 [============================>.] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0024
# Epoch 54: val_loss did not improve from 0.00135
# 240/240 [==============================] - 2s 9ms/step - loss: 0.0013 - root_mean_squared_error: 0.0024 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0024 - lr: 1.9000e-06
# Epoch 55/300
# 236/240 [============================>.] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0024
# Epoch 55: val_loss did not improve from 0.00135
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0014 - root_mean_squared_error: 0.0024 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0024 - lr: 1.9000e-06
# Epoch 56/300
# 235/240 [============================>.] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0024
# Epoch 56: val_loss improved from 0.00135 to 0.00135, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/fc/asi_fc_weights.hdf5
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0013 - root_mean_squared_error: 0.0024 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0024 - lr: 1.9000e-06
# Epoch 57/300
# 240/240 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0024
# Epoch 57: val_loss improved from 0.00135 to 0.00135, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/fc/asi_fc_weights.hdf5
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0013 - root_mean_squared_error: 0.0024 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0024 - lr: 1.9000e-07
# Epoch 58/300
# 237/240 [============================>.] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0024
# Epoch 58: val_loss did not improve from 0.00135
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0013 - root_mean_squared_error: 0.0024 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0024 - lr: 1.9000e-07
# Epoch 59/300
# 234/240 [============================>.] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0024
# Epoch 59: val_loss did not improve from 0.00135
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0013 - root_mean_squared_error: 0.0024 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0024 - lr: 1.9000e-07
# Epoch 60/300
# 235/240 [============================>.] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0024
# Epoch 60: val_loss improved from 0.00135 to 0.00135, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/fc/asi_fc_weights.hdf5
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0013 - root_mean_squared_error: 0.0024 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0024 - lr: 1.9000e-07
# Epoch 61/300
# 236/240 [============================>.] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0024
# Epoch 61: val_loss did not improve from 0.00135
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0013 - root_mean_squared_error: 0.0024 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0024 - lr: 1.9000e-07
# Epoch 62/300
# 237/240 [============================>.] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0024
# Epoch 62: val_loss improved from 0.00135 to 0.00134, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/fc/asi_fc_weights.hdf5
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0013 - root_mean_squared_error: 0.0024 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0024 - lr: 1.9000e-08
# Epoch 63/300
# 240/240 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0024
# Epoch 63: val_loss did not improve from 0.00134
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0013 - root_mean_squared_error: 0.0024 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0024 - lr: 1.9000e-08
# Epoch 64/300
# 239/240 [============================>.] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0024
# Epoch 64: val_loss did not improve from 0.00134
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0013 - root_mean_squared_error: 0.0024 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0024 - lr: 1.9000e-08
# Epoch 65/300
# 237/240 [============================>.] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0024
# Epoch 65: val_loss did not improve from 0.00134
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0013 - root_mean_squared_error: 0.0024 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0024 - lr: 1.9000e-08
# Epoch 66/300
# 239/240 [============================>.] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0024
# Epoch 66: val_loss did not improve from 0.00134
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0013 - root_mean_squared_error: 0.0024 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0024 - lr: 1.9000e-08
# Epoch 67/300
# 240/240 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0024
# Epoch 67: val_loss did not improve from 0.00134
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0013 - root_mean_squared_error: 0.0024 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0024 - lr: 1.9000e-09
# Epoch 68/300
# 238/240 [============================>.] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0024
# Epoch 68: val_loss did not improve from 0.00134
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0013 - root_mean_squared_error: 0.0024 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0024 - lr: 1.9000e-09
# Epoch 69/300
# 235/240 [============================>.] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0024
# Epoch 69: val_loss did not improve from 0.00134
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0013 - root_mean_squared_error: 0.0024 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0024 - lr: 1.9000e-09
# Epoch 70/300
# 236/240 [============================>.] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0024
# Epoch 70: val_loss did not improve from 0.00134
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0013 - root_mean_squared_error: 0.0024 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0024 - lr: 1.9000e-09
# Epoch 71/300
# 236/240 [============================>.] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0024
# Epoch 71: val_loss did not improve from 0.00134
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0013 - root_mean_squared_error: 0.0024 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0024 - lr: 1.9000e-09
# Epoch 72/300
# 240/240 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0024
# Epoch 72: val_loss did not improve from 0.00134
# 240/240 [==============================] - 2s 8ms/step - loss: 0.0013 - root_mean_squared_error: 0.0024 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0024 - lr: 1.9000e-10
# self.input_phenomenon.shape Tensor("IteratorGetNext:0", shape=(None, 12), dtype=float32)
# self.source_distance.shape (None, 20)
# self.context.shape (None, 20, 14)
# self.n2v.shape (None, 21, 12)
# att_query.shape, att_value.shape (None, 1, 64) (None, 20, 64)
# att_output (None, 64)
# 520/520 [==============================] - 2s 3ms/step
# 2079/2079 [==============================] - 6s 3ms/step
# self.input_phenomenon.shape Tensor("IteratorGetNext:0", shape=(None, 12), dtype=float32)
# self.source_distance.shape (None, 20)
# self.context.shape (None, 20, 14)
# self.n2v.shape (None, 21, 12)
# att_query.shape, att_value.shape (None, 1, 64) (None, 20, 64)
# att_output (None, 64)
# 267/267 [==============================] - 1s 3ms/step
# self.input_phenomenon.shape Tensor("IteratorGetNext:0", shape=(None, 12), dtype=float32)
# self.source_distance.shape (None, 20)
# self.context.shape (None, 20, 14)
# self.n2v.shape (None, 21, 12)
# att_query.shape, att_value.shape (None, 1, 64) (None, 20, 64)
# att_output (None, 64)
# 67/67 [==============================] - 0s 3ms/step
# self.input_phenomenon.shape Tensor("IteratorGetNext:0", shape=(None, 12), dtype=float32)
# self.source_distance.shape (None, 20)
# self.context.shape (None, 20, 14)
# self.n2v.shape (None, 21, 12)
# att_query.shape, att_value.shape (None, 1, 64) (None, 20, 64)
# att_output (None, 64)
# 267/267 [==============================] - 1s 3ms/step
# self.input_phenomenon.shape Tensor("IteratorGetNext:0", shape=(None, 12), dtype=float32)
# self.source_distance.shape (None, 20)
# self.context.shape (None, 20, 14)
# self.n2v.shape (None, 21, 12)
# att_query.shape, att_value.shape (None, 1, 64) (None, 20, 64)
# att_output (None, 64)
# 67/67 [==============================] - 0s 3ms/step

# %%
print('################# Test ##########################')
print('MALE test:.... {}'.format(result[0]))
print('RMSE test:.... {}'.format(result[1]))
print('MAPE test:.... {}'.format(result[2]))
print('################# Train ##########################')
print('MALE train:.... {}'.format(result[3]))
print('RMSE train:.... {}'.format(result[4]))
print('MAPE train:.... {}'.format(result[5]))
# Out:
# ################# Test ##########################
# MALE test:.... 0.008133738049205754
# RMSE test:.... 1747.3723728336251
# MAPE test:.... 0.637549803080647
# ################# Train ##########################
# MALE train:.... 0.001334840119532978
# RMSE train:.... 531.254295115684
# MAPE train:.... 0.083925485322016

# %%
from sklearn.metrics import r2_score
import numpy as np

# metric
def metric(pred, label):
    assert label.shape == pred.shape
    
    with np.errstate(divide = 'ignore', invalid = 'ignore'):
        mask = np.not_equal(label, 0)
        mask = mask.astype(np.float32)
        mask /= np.mean(mask)
        male = np.abs(np.subtract(np.log(pred), np.log(label))).astype(np.float32)
        male = np.nan_to_num(male * mask)
        male = np.mean(male)
        mae = np.abs(np.subtract(pred, label)).astype(np.float32)
        rmse = np.square(mae)
        mape = np.divide(mae, label)
        mae = np.nan_to_num(mae * mask)
        mae = np.mean(mae)
        rmse = np.nan_to_num(rmse * mask)
        rmse = np.sqrt(np.mean(rmse))
        mape = np.nan_to_num(mape * mask)
        mape = np.median(mape) # np.mean(mape) -- author leverages median
    return male, rmse, mape

# %%
y_label = np.exp(dataset.y_test)
y_pred = np.exp(result[6].flatten())
metric(y_pred, y_label) # should be same value
# Out:
# (0.008133738, 1747.3724, 0.006375498030806689)

# %%
plt.scatter(y_label, y_pred)
