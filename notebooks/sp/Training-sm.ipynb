# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]= '3'

# %%
# %matplotlib inline

import sys
sys.path.append("../../")

from train_model_sm import train

from sklearn.linear_model import LinearRegression
from yellowbrick.regressor import ResidualsPlot, PredictionError

import seaborn as sns
import matplotlib.pyplot as plt

from matplotlib import rcParams
rcParams['figure.figsize'] = (8, 4)
rcParams['figure.dpi'] = 100
rcParams['font.size'] = 8
rcParams['font.family'] = 'sans-serif'
rcParams['axes.facecolor'] = '#ffffff'
rcParams['lines.linewidth'] = 2.0
# Out:
# 2023-08-22 00:16:02.051737: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
hyperparameter={
"num_nearest":60,
"sigma":10,
"learning_rate":0.001,
"batch_size":250,
"num_neuron":60,
"num_layers":2,
"size_embedded":50,
"num_nearest_geo":60,
"num_nearest_eucli":60,
"id_dataset":'sp',
"epochs":300,
"optimier":'adam',
"validation_split":0.1,
"label":'asi_sp',
"early_stopping": False,
"graph_label":'matrix',
"sequence":'_normalized'
}

# %% [markdown]
# # Model

# %%
spatial = train(**hyperparameter)

# %%
dataset,\
result,\
fit,\
embedded_train,\
embedded_test,\
predict_regression_train,\
predict_regression_test = spatial()
# Out:
# node2vec (68848, 8)
# self.dist_eucli.shape, self.context_struc_eucli_target.shape, self.n2v_eucli.shape (None, 60) (None, 60, 9) (None, 61, 8)
# self.dist_geo.shape, self.context_geo_target_dist.shape, self.n2v_geo.shape (None, 60) (None, 60, 10) (None, 61, 8)
# WARNING:tensorflow:From /home/smhan/.conda/envs/TF2/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# 2023-08-22 00:16:04.093491: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-22 00:16:04.097363: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-22 00:16:04.097608: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-22 00:16:04.098302: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-22 00:16:04.100855: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-22 00:16:04.101100: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-22 00:16:04.101320: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-22 00:16:04.453430: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-22 00:16:04.453710: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-22 00:16:04.453936: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-22 00:16:04.454152: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22273 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:c1:00.0, compute capability: 8.6
# self.input_phenomenon.shape Tensor("Placeholder:0", shape=(None, 8), dtype=float32)
# self.source_distance.shape (None, 60)
# self.context.shape (None, 60, 10)
# self.n2v.shape (None, 61, 8)
# att_query.shape, att_value.shape (None, 1, 64) (None, 60, 64)
# att_output (None, 64)
# feedforward (None, 60)
# Epoch 1/300
# self.input_phenomenon.shape Tensor("IteratorGetNext:0", shape=(None, 8), dtype=float32)
# self.source_distance.shape (None, 60)
# self.context.shape (None, 60, 10)
# self.n2v.shape (None, 61, 8)
# att_query.shape, att_value.shape (None, 1, 64) (None, 60, 64)
# att_output (None, 64)
# self.input_phenomenon.shape Tensor("IteratorGetNext:0", shape=(None, 8), dtype=float32)
# self.source_distance.shape (None, 60)
# self.context.shape (None, 60, 10)
# self.n2v.shape (None, 61, 8)
# att_query.shape, att_value.shape (None, 1, 64) (None, 60, 64)
# att_output (None, 64)
# 2023-08-22 00:16:08.124518: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-08-22 00:16:08.132715: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x563f7c664450 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-08-22 00:16:08.132757: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2023-08-22 00:16:08.137865: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-08-22 00:16:08.227362: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 197/199 [============================>.] - ETA: 0s - loss: 0.8563 - root_mean_squared_error: 2.5472self.input_phenomenon.shape Tensor("IteratorGetNext:0", shape=(None, 8), dtype=float32)
# self.source_distance.shape (None, 60)
# self.context.shape (None, 60, 10)
# self.n2v.shape (None, 61, 8)
# att_query.shape, att_value.shape (None, 1, 64) (None, 60, 64)
# att_output (None, 64)
#
# Epoch 1: val_loss improved from inf to 0.10463, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 6s 10ms/step - loss: 0.8514 - root_mean_squared_error: 2.5390 - val_loss: 0.1046 - val_root_mean_squared_error: 0.1179 - lr: 0.0010
# Epoch 2/300
# 196/199 [============================>.] - ETA: 0s - loss: 0.0873 - root_mean_squared_error: 0.0989
# Epoch 2: val_loss improved from 0.10463 to 0.03509, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 9ms/step - loss: 0.0875 - root_mean_squared_error: 0.0990 - val_loss: 0.0351 - val_root_mean_squared_error: 0.0509 - lr: 0.0010
# Epoch 3/300
# 196/199 [============================>.] - ETA: 0s - loss: 0.1088 - root_mean_squared_error: 0.1342
# Epoch 3: val_loss did not improve from 0.03509
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1086 - root_mean_squared_error: 0.1339 - val_loss: 0.1330 - val_root_mean_squared_error: 0.1406 - lr: 0.0010
# Epoch 4/300
# 198/199 [============================>.] - ETA: 0s - loss: 0.0911 - root_mean_squared_error: 0.1038
# Epoch 4: val_loss did not improve from 0.03509
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0910 - root_mean_squared_error: 0.1037 - val_loss: 0.0544 - val_root_mean_squared_error: 0.0585 - lr: 0.0010
# Epoch 5/300
# 194/199 [============================>.] - ETA: 0s - loss: 0.0484 - root_mean_squared_error: 0.0554
# Epoch 5: val_loss did not improve from 0.03509
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0478 - root_mean_squared_error: 0.0549 - val_loss: 0.0415 - val_root_mean_squared_error: 0.0437 - lr: 0.0010
# Epoch 6/300
# 194/199 [============================>.] - ETA: 0s - loss: 0.0627 - root_mean_squared_error: 0.0767
# Epoch 6: val_loss did not improve from 0.03509
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0624 - root_mean_squared_error: 0.0762 - val_loss: 0.0384 - val_root_mean_squared_error: 0.0420 - lr: 0.0010
# Epoch 7/300
# 192/199 [===========================>..] - ETA: 0s - loss: 0.0482 - root_mean_squared_error: 0.0574
# Epoch 7: val_loss improved from 0.03509 to 0.02221, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0481 - root_mean_squared_error: 0.0572 - val_loss: 0.0222 - val_root_mean_squared_error: 0.0277 - lr: 0.0010
# Epoch 8/300
# 194/199 [============================>.] - ETA: 0s - loss: 0.0558 - root_mean_squared_error: 0.0654
# Epoch 8: val_loss did not improve from 0.02221
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0561 - root_mean_squared_error: 0.0657 - val_loss: 0.0389 - val_root_mean_squared_error: 0.0436 - lr: 0.0010
# Epoch 9/300
# 194/199 [============================>.] - ETA: 0s - loss: 0.0607 - root_mean_squared_error: 0.0715
# Epoch 9: val_loss did not improve from 0.02221
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0607 - root_mean_squared_error: 0.0714 - val_loss: 0.1194 - val_root_mean_squared_error: 0.1221 - lr: 0.0010
# Epoch 10/300
# 194/199 [============================>.] - ETA: 0s - loss: 0.0725 - root_mean_squared_error: 0.0798
# Epoch 10: val_loss did not improve from 0.02221
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0722 - root_mean_squared_error: 0.0795 - val_loss: 0.0714 - val_root_mean_squared_error: 0.0765 - lr: 0.0010
# Epoch 11/300
# 199/199 [==============================] - ETA: 0s - loss: 0.0410 - root_mean_squared_error: 0.0476
# Epoch 11: val_loss did not improve from 0.02221
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0410 - root_mean_squared_error: 0.0476 - val_loss: 0.0287 - val_root_mean_squared_error: 0.0339 - lr: 0.0010
# Epoch 12/300
# 198/199 [============================>.] - ETA: 0s - loss: 0.0362 - root_mean_squared_error: 0.0401
# Epoch 12: val_loss did not improve from 0.02221
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0362 - root_mean_squared_error: 0.0402 - val_loss: 0.0414 - val_root_mean_squared_error: 0.0449 - lr: 0.0010
# Epoch 13/300
# 199/199 [==============================] - ETA: 0s - loss: 0.0073 - root_mean_squared_error: 0.0117
# Epoch 13: val_loss improved from 0.02221 to 0.00530, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0073 - root_mean_squared_error: 0.0117 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0079 - lr: 1.0000e-04
# Epoch 14/300
# 195/199 [============================>.] - ETA: 0s - loss: 0.0050 - root_mean_squared_error: 0.0078
# Epoch 14: val_loss improved from 0.00530 to 0.00494, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0050 - root_mean_squared_error: 0.0079 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0074 - lr: 1.0000e-04
# Epoch 15/300
# 193/199 [============================>.] - ETA: 0s - loss: 0.0045 - root_mean_squared_error: 0.0071
# Epoch 15: val_loss improved from 0.00494 to 0.00431, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0045 - root_mean_squared_error: 0.0071 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0064 - lr: 1.0000e-04
# Epoch 16/300
# 196/199 [============================>.] - ETA: 0s - loss: 0.0043 - root_mean_squared_error: 0.0067
# Epoch 16: val_loss improved from 0.00431 to 0.00385, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0043 - root_mean_squared_error: 0.0067 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0060 - lr: 1.0000e-04
# Epoch 17/300
# 199/199 [==============================] - ETA: 0s - loss: 0.0041 - root_mean_squared_error: 0.0063
# Epoch 17: val_loss improved from 0.00385 to 0.00353, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0041 - root_mean_squared_error: 0.0063 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0055 - lr: 1.0000e-04
# Epoch 18/300
# 198/199 [============================>.] - ETA: 0s - loss: 0.0048 - root_mean_squared_error: 0.0068
# Epoch 18: val_loss did not improve from 0.00353
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0048 - root_mean_squared_error: 0.0068 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0073 - lr: 1.0000e-04
# Epoch 19/300
# 196/199 [============================>.] - ETA: 0s - loss: 0.0055 - root_mean_squared_error: 0.0073
# Epoch 19: val_loss did not improve from 0.00353
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0055 - root_mean_squared_error: 0.0073 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0057 - lr: 1.0000e-04
# Epoch 20/300
# 197/199 [============================>.] - ETA: 0s - loss: 0.0046 - root_mean_squared_error: 0.0064
# Epoch 20: val_loss did not improve from 0.00353
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0046 - root_mean_squared_error: 0.0064 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0050 - lr: 1.0000e-04
# Epoch 21/300
# 194/199 [============================>.] - ETA: 0s - loss: 0.0034 - root_mean_squared_error: 0.0052
# Epoch 21: val_loss did not improve from 0.00353
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0034 - root_mean_squared_error: 0.0052 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0049 - lr: 1.0000e-04
# Epoch 22/300
# 198/199 [============================>.] - ETA: 0s - loss: 0.0041 - root_mean_squared_error: 0.0058
# Epoch 22: val_loss improved from 0.00353 to 0.00320, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 9ms/step - loss: 0.0041 - root_mean_squared_error: 0.0058 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0048 - lr: 1.0000e-04
# Epoch 23/300
# 199/199 [==============================] - ETA: 0s - loss: 0.0033 - root_mean_squared_error: 0.0049
# Epoch 23: val_loss improved from 0.00320 to 0.00254, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0033 - root_mean_squared_error: 0.0049 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0040 - lr: 1.0000e-04
# Epoch 24/300
# 197/199 [============================>.] - ETA: 0s - loss: 0.0057 - root_mean_squared_error: 0.0072
# Epoch 24: val_loss did not improve from 0.00254
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0057 - root_mean_squared_error: 0.0072 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0084 - lr: 1.0000e-04
# Epoch 25/300
# 199/199 [==============================] - ETA: 0s - loss: 0.0045 - root_mean_squared_error: 0.0061
# Epoch 25: val_loss did not improve from 0.00254
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0045 - root_mean_squared_error: 0.0061 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0097 - lr: 1.0000e-04
# Epoch 26/300
# 196/199 [============================>.] - ETA: 0s - loss: 0.0039 - root_mean_squared_error: 0.0054
# Epoch 26: val_loss did not improve from 0.00254
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0039 - root_mean_squared_error: 0.0054 - val_loss: 0.0107 - val_root_mean_squared_error: 0.0112 - lr: 1.0000e-04
# Epoch 27/300
# 194/199 [============================>.] - ETA: 0s - loss: 0.0051 - root_mean_squared_error: 0.0065
# Epoch 27: val_loss did not improve from 0.00254
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0050 - root_mean_squared_error: 0.0064 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0047 - lr: 1.0000e-04
# Epoch 28/300
# 193/199 [============================>.] - ETA: 0s - loss: 0.0052 - root_mean_squared_error: 0.0065
# Epoch 28: val_loss did not improve from 0.00254
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0053 - root_mean_squared_error: 0.0066 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0046 - lr: 1.0000e-04
# Epoch 29/300
# 194/199 [============================>.] - ETA: 0s - loss: 0.0022 - root_mean_squared_error: 0.0036
# Epoch 29: val_loss improved from 0.00254 to 0.00204, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0022 - root_mean_squared_error: 0.0036 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0034 - lr: 1.0000e-05
# Epoch 30/300
# 199/199 [==============================] - ETA: 0s - loss: 0.0021 - root_mean_squared_error: 0.0035
# Epoch 30: val_loss improved from 0.00204 to 0.00203, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0021 - root_mean_squared_error: 0.0035 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0034 - lr: 1.0000e-05
# Epoch 31/300
# 193/199 [============================>.] - ETA: 0s - loss: 0.0021 - root_mean_squared_error: 0.0035
# Epoch 31: val_loss did not improve from 0.00203
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0021 - root_mean_squared_error: 0.0035 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0034 - lr: 1.0000e-05
# Epoch 32/300
# 196/199 [============================>.] - ETA: 0s - loss: 0.0021 - root_mean_squared_error: 0.0034
# Epoch 32: val_loss improved from 0.00203 to 0.00200, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0021 - root_mean_squared_error: 0.0034 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0033 - lr: 1.0000e-05
# Epoch 33/300
# 199/199 [==============================] - ETA: 0s - loss: 0.0020 - root_mean_squared_error: 0.0034
# Epoch 33: val_loss did not improve from 0.00200
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0020 - root_mean_squared_error: 0.0034 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0035 - lr: 1.0000e-05
# Epoch 34/300
# 199/199 [==============================] - ETA: 0s - loss: 0.0020 - root_mean_squared_error: 0.0034
# Epoch 34: val_loss improved from 0.00200 to 0.00195, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 9ms/step - loss: 0.0020 - root_mean_squared_error: 0.0034 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0034 - lr: 1.0000e-05
# Epoch 35/300
# 198/199 [============================>.] - ETA: 0s - loss: 0.0020 - root_mean_squared_error: 0.0033
# Epoch 35: val_loss improved from 0.00195 to 0.00194, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0020 - root_mean_squared_error: 0.0033 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0033 - lr: 1.0000e-06
# Epoch 36/300
# 197/199 [============================>.] - ETA: 0s - loss: 0.0020 - root_mean_squared_error: 0.0033
# Epoch 36: val_loss improved from 0.00194 to 0.00194, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0020 - root_mean_squared_error: 0.0033 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0033 - lr: 1.0000e-06
# Epoch 37/300
# 198/199 [============================>.] - ETA: 0s - loss: 0.0020 - root_mean_squared_error: 0.0033
# Epoch 37: val_loss did not improve from 0.00194
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0020 - root_mean_squared_error: 0.0033 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0033 - lr: 1.0000e-06
# Epoch 38/300
# 198/199 [============================>.] - ETA: 0s - loss: 0.0020 - root_mean_squared_error: 0.0033
# Epoch 38: val_loss improved from 0.00194 to 0.00191, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 9ms/step - loss: 0.0020 - root_mean_squared_error: 0.0033 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0032 - lr: 1.0000e-06
# Epoch 39/300
# 197/199 [============================>.] - ETA: 0s - loss: 0.0020 - root_mean_squared_error: 0.0033
# Epoch 39: val_loss did not improve from 0.00191
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0020 - root_mean_squared_error: 0.0033 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0032 - lr: 1.0000e-06
# Epoch 40/300
# 194/199 [============================>.] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0033
# Epoch 40: val_loss did not improve from 0.00191
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0019 - root_mean_squared_error: 0.0033 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0032 - lr: 1.0000e-06
# Epoch 41/300
# 198/199 [============================>.] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0033
# Epoch 41: val_loss did not improve from 0.00191
# 199/199 [==============================] - 2s 9ms/step - loss: 0.0019 - root_mean_squared_error: 0.0033 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0032 - lr: 1.0000e-06
# Epoch 42/300
# 198/199 [============================>.] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0033
# Epoch 42: val_loss improved from 0.00191 to 0.00190, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 9ms/step - loss: 0.0019 - root_mean_squared_error: 0.0033 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0032 - lr: 1.0000e-07
# Epoch 43/300
# 193/199 [============================>.] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0033
# Epoch 43: val_loss improved from 0.00190 to 0.00190, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0019 - root_mean_squared_error: 0.0033 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0032 - lr: 1.0000e-07
# Epoch 44/300
# 197/199 [============================>.] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0033
# Epoch 44: val_loss improved from 0.00190 to 0.00189, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0019 - root_mean_squared_error: 0.0033 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0032 - lr: 1.0000e-07
# Epoch 45/300
# 198/199 [============================>.] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0033
# Epoch 45: val_loss improved from 0.00189 to 0.00189, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 9ms/step - loss: 0.0019 - root_mean_squared_error: 0.0033 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0032 - lr: 1.0000e-07
# Epoch 46/300
# 199/199 [==============================] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0033
# Epoch 46: val_loss did not improve from 0.00189
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0019 - root_mean_squared_error: 0.0033 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0032 - lr: 1.0000e-07
# Epoch 47/300
# 194/199 [============================>.] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0033
# Epoch 47: val_loss did not improve from 0.00189
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0019 - root_mean_squared_error: 0.0033 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0032 - lr: 1.0000e-08
# Epoch 48/300
# 199/199 [==============================] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0033
# Epoch 48: val_loss did not improve from 0.00189
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0019 - root_mean_squared_error: 0.0033 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0032 - lr: 1.0000e-08
# Epoch 49/300
# 199/199 [==============================] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0033
# Epoch 49: val_loss did not improve from 0.00189
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0019 - root_mean_squared_error: 0.0033 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0032 - lr: 1.0000e-08
# Epoch 50/300
# 193/199 [============================>.] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0033
# Epoch 50: val_loss did not improve from 0.00189
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0019 - root_mean_squared_error: 0.0033 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0032 - lr: 1.0000e-08
# Epoch 51/300
# 193/199 [============================>.] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0033
# Epoch 51: val_loss did not improve from 0.00189
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0019 - root_mean_squared_error: 0.0033 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0032 - lr: 1.0000e-08
# Epoch 52/300
# 197/199 [============================>.] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0033
# Epoch 52: val_loss did not improve from 0.00189
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0019 - root_mean_squared_error: 0.0033 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0032 - lr: 1.0000e-09
# Epoch 53/300
# 196/199 [============================>.] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0033
# Epoch 53: val_loss did not improve from 0.00189
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0019 - root_mean_squared_error: 0.0033 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0032 - lr: 1.0000e-09
# Epoch 54/300
# 198/199 [============================>.] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0033
# Epoch 54: val_loss improved from 0.00189 to 0.00189, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0019 - root_mean_squared_error: 0.0033 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0032 - lr: 1.0000e-09
# Epoch 55/300
# 195/199 [============================>.] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0033
# Epoch 55: val_loss did not improve from 0.00189
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0019 - root_mean_squared_error: 0.0033 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0032 - lr: 1.0000e-09
# Epoch 56/300
# 194/199 [============================>.] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0033
# Epoch 56: val_loss did not improve from 0.00189
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0019 - root_mean_squared_error: 0.0033 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0032 - lr: 1.0000e-09
# Epoch 57/300
# 197/199 [============================>.] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0033
# Epoch 57: val_loss did not improve from 0.00189
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0019 - root_mean_squared_error: 0.0033 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0032 - lr: 1.0000e-10
# Epoch 58/300
# 198/199 [============================>.] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0033
# Epoch 58: val_loss did not improve from 0.00189
# 199/199 [==============================] - 2s 9ms/step - loss: 0.0019 - root_mean_squared_error: 0.0033 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0032 - lr: 1.0000e-10
# Epoch 59/300
# 199/199 [==============================] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0033
# Epoch 59: val_loss did not improve from 0.00189
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0019 - root_mean_squared_error: 0.0033 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0032 - lr: 1.0000e-10
# Epoch 60/300
# 195/199 [============================>.] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0033
# Epoch 60: val_loss did not improve from 0.00189
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0019 - root_mean_squared_error: 0.0033 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0032 - lr: 1.0000e-10
# Epoch 61/300
# 197/199 [============================>.] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0033
# Epoch 61: val_loss did not improve from 0.00189
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0019 - root_mean_squared_error: 0.0033 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0032 - lr: 1.0000e-10
# Epoch 62/300
# 193/199 [============================>.] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0033
# Epoch 62: val_loss did not improve from 0.00189
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0019 - root_mean_squared_error: 0.0033 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0032 - lr: 1.0000e-11
# Epoch 63/300
# 195/199 [============================>.] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0033
# Epoch 63: val_loss did not improve from 0.00189
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0019 - root_mean_squared_error: 0.0033 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0032 - lr: 1.0000e-11
# Epoch 64/300
# 197/199 [============================>.] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0033
# Epoch 64: val_loss did not improve from 0.00189
# 199/199 [==============================] - 2s 8ms/step - loss: 0.0019 - root_mean_squared_error: 0.0033 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0032 - lr: 1.0000e-11
# self.input_phenomenon.shape Tensor("IteratorGetNext:0", shape=(None, 8), dtype=float32)
# self.source_distance.shape (None, 60)
# self.context.shape (None, 60, 10)
# self.n2v.shape (None, 61, 8)
# att_query.shape, att_value.shape (None, 1, 64) (None, 60, 64)
# att_output (None, 64)
# 431/431 [==============================] - 1s 3ms/step
# 1722/1722 [==============================] - 5s 3ms/step
# self.input_phenomenon.shape Tensor("IteratorGetNext:0", shape=(None, 8), dtype=float32)
# self.source_distance.shape (None, 60)
# self.context.shape (None, 60, 10)
# self.n2v.shape (None, 61, 8)
# att_query.shape, att_value.shape (None, 1, 64) (None, 60, 64)
# att_output (None, 64)
# 221/221 [==============================] - 1s 3ms/step
# self.input_phenomenon.shape Tensor("IteratorGetNext:0", shape=(None, 8), dtype=float32)
# self.source_distance.shape (None, 60)
# self.context.shape (None, 60, 10)
# self.n2v.shape (None, 61, 8)
# att_query.shape, att_value.shape (None, 1, 64) (None, 60, 64)
# att_output (None, 64)
# 56/56 [==============================] - 0s 3ms/step
# self.input_phenomenon.shape Tensor("IteratorGetNext:0", shape=(None, 8), dtype=float32)
# self.source_distance.shape (None, 60)
# self.context.shape (None, 60, 10)
# self.n2v.shape (None, 61, 8)
# att_query.shape, att_value.shape (None, 1, 64) (None, 60, 64)
# att_output (None, 64)
# 221/221 [==============================] - 1s 3ms/step
# self.input_phenomenon.shape Tensor("IteratorGetNext:0", shape=(None, 8), dtype=float32)
# self.source_distance.shape (None, 60)
# self.context.shape (None, 60, 10)
# self.n2v.shape (None, 61, 8)
# att_query.shape, att_value.shape (None, 1, 64) (None, 60, 64)
# att_output (None, 64)
# 56/56 [==============================] - 0s 3ms/step

# %%
print('################# Test ##########################')
print('MALE test:.... {}'.format(result[0]))
print('RMSE test:.... {}'.format(result[1]))
print('MAPE test:.... {}'.format(result[2]))
print('################# Train ##########################')
print('MALE train:.... {}'.format(result[3]))
print('RMSE train:.... {}'.format(result[4]))
print('MAPE train:.... {}'.format(result[5]))
# Out:
# ################# Test ##########################
# MALE test:.... 0.004479184124017588
# RMSE test:.... 4271.873503748934
# MAPE test:.... 0.42788894254483495
# ################# Train ##########################
# MALE train:.... 0.0019301179575574407
# RMSE train:.... 3080.871429312896
# MAPE train:.... 0.1344876714910973

# %%
from sklearn.metrics import r2_score
import numpy as np

# metric
def metric(pred, label):
    assert label.shape == pred.shape
    
    with np.errstate(divide = 'ignore', invalid = 'ignore'):
        mask = np.not_equal(label, 0)
        mask = mask.astype(np.float32)
        mask /= np.mean(mask)
        male = np.abs(np.subtract(np.log(pred), np.log(label))).astype(np.float32)
        male = np.nan_to_num(male * mask)
        male = np.mean(male)
        mae = np.abs(np.subtract(pred, label)).astype(np.float32)
        rmse = np.square(mae)
        mape = np.divide(mae, label)
        mae = np.nan_to_num(mae * mask)
        mae = np.mean(mae)
        rmse = np.nan_to_num(rmse * mask)
        rmse = np.sqrt(np.mean(rmse))
        mape = np.nan_to_num(mape * mask)
        mape = np.median(mape) # np.mean(mape) -- author leverages median
    return male, rmse, mape

# %%
y_label = np.exp(dataset.y_test)
y_pred = np.exp(result[6].flatten())
metric(y_pred, y_label) # should be same value
# Out:
# (0.0044791843, 4271.8735, 0.004278889425447971)

# %%
plt.scatter(y_label, y_pred)

# %% [markdown]
# # Display Model Training History

# %%
rcParams['figure.figsize'] = (16, 6)
# summarize history for loss
plt.plot(fit.history['loss'])
plt.plot(fit.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %% [markdown]
# # Residue

# %% [markdown]
# ## Raw

# %%
# Instantiate the linear model and visualizer
regressor = LinearRegression()
visualizer = ResidualsPlot(regressor);

visualizer.fit(dataset.X_train, dataset.y_train);  # Fit the training data to the model
visualizer.score(dataset.X_test, dataset.y_test);  # Evaluate the model on the test data
visualizer.poof();                 # Draw/show/poof the data

# %%
# Instantiate the linear model and visualizer
regression = LinearRegression()
visualizer = PredictionError(regression);

visualizer.fit(dataset.X_train, dataset.y_train);  # Fit the training data to the visualizer
visualizer.score(dataset.X_test, dataset.y_test);  # Evaluate the model on the test data
g = visualizer.poof();            # Draw/show/poof the data

# %% [markdown]
# ## Embedded

# %%
# Instantiate the linear model and visualizer
regressor = LinearRegression()
visualizer = ResidualsPlot(regressor)

visualizer.fit(embedded_train, dataset.y_train)  # Fit the training data to the model
visualizer.score(embedded_test, dataset.y_test)  # Evaluate the model on the test data
visualizer.poof();                 # Draw/show/poof the data

# %%
# Instantiate the linear model and visualizer
regression = LinearRegression()
visualizer = PredictionError(regression)

visualizer.fit(embedded_train, dataset.y_train)  # Fit the training data to the visualizer
visualizer.score(embedded_test, dataset.y_test)  # Evaluate the model on the test data
g = visualizer.poof()             # Draw/show/poof the data
